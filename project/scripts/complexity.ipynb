# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
module_path = os.path.abspath(os.path.join('.'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
mentions= [62250, 74700, 87150, 99600, 112050, 124500, 136950, 149400, 161850, 174300, 186750]
times_eids= [7.6250762559993746, 11.337807924001027, 15.586896001999776, 20.247150250999766, 25.34528938800031, 31.62441506399955, 38.67183062699951, 46.85308975599946, 54.826479432998894, 65.33506137699987, 73.65203261200077]

# %%
x_linears = [mentions[0], mentions[-1]]
times_linears = [times_eids[0], times_eids[-1]]

# %%
import numpy as np

# %%
times_eids = [np.round(t, 3) for t in times_eids]

# %%
times_eids
# Out:
# [7.625,
#  11.338,
#  15.587,
#  20.247,
#  25.345,
#  31.624,
#  38.672,
#  46.853,
#  54.826,
#  65.335,
#  73.652]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 11})
# Use ggplot style for more appealing visuals


# Sample data for the curve
x = mentions  # 100 points from 0 to 10
y = times_eids  # Sin function for the y values

# Creating the plot
plt.plot(mentions, times_eids)
plt.plot(x_linears, times_linears, color="blue", linestyle='dotted', alpha=0.5)

# Updating the code with axis labels
plt.xlabel('Mention Count')
plt.ylabel('Elapsed Time (sec)')
plt.xticks(rotation=15)
# Display the plot
# plt.show()
plt.savefig("complexity.pdf", bbox_inches='tight')
